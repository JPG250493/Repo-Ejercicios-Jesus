# %% [markdown]
# ## PRACTICA OBLIGATORIA: **APIs en Produccion**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en... **¡que no hay práctica obligatoria!**
#
# * El objetivo de esta unidad es que te familiarices con las *APIs en Producción*.
#
# * **Importante**, recuerda descargar este notebook en tu ordenador y subirlo, tal y como está ahora, a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y poder asistir a la sesión.
