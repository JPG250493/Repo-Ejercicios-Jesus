# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre conceptos básicos de Matplotlib, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Ejercicio 1
#
# Construye la siguiente figura con dos subplots utilizando el estilo MATLAB (es decir plt.\<funcion\>, no usando objetos `Axes`)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
fig = plt.figure()
plt.subplot(1,2,1)
plt.plot(x, np.sin(x))
plt.title("Seno")

plt.subplot(1,2,2)
plt.plot(x, np.cos(x))
plt.title("Coseno");

# %% [markdown]
# ### Ejercicio 2
#
# Reproduce la imagen de la figura usando tres subplots en una columna, utilizando objetos `Axes`. Las dos primeras son las funciones anteriores y la tercera es la tangente (np.tan)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(8, 8))
plt.subplot(3,1,1)
plt.plot(x,np.sin(x), "red")
plt.subplot(3,1,2)
plt.plot(x, np.cos(x), "green")
plt.subplot(3,1,3)
plt.plot(x,np.tan(x), "blue");
# plt.ylim(-50, 30);

# %% [markdown]
# ### Ejercicio 3: Ajuste de Colores y Estilos de Línea
#
# Modifica la primera figura para que se muestre de la siguiente manera

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
plt.figure(figsize=(8, 8))
plt.subplot(1,2,1)
plt.plot(x,
         np.sin(2*x),
         color="#e596e5", 
         linestyle = "--")
plt.subplot(1,2,2)
plt.plot(x,
         np.cos(2*x),
         color = "#38cdcd",
         linestyle ="--");

# %% [markdown]
# ### Ejercicio 4
#
# Reproduce la figura siguiente. Recuerda que las funciones seno hiperbólico y coseno hiperbólico se obtienen así:
# * np.sinh, seno hiperbólico;
# * np.cosh, coseno hiperbólico;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10, 
                    10))
plt.subplot(2,1,1)
plt.plot(x,
         np.sinh(x),
         "red")
plt.title("Seno Hiperbólico")
plt.xlabel("x")
plt.ylabel("sinh(x)")
plt.subplot(2,1,2)
plt.plot(x,
         np.cosh(x),
         "blue")
plt.title("Coseno Hiperbólico")
plt.xlabel("x")
plt.ylabel("cosh(x)")

plt.tight_layout() #ajusta automáticamente los parámetros de espaciado para que los títulos, etiquetas de eje y etiquetas X/Y de los diferentes subgráficos no se superpongan ni queden demasiado apretados.
plt.show();

# %% [markdown]
# ### Ejercicio 5: Ajustando el Espaciado de Subplots
#
# Reproduce la siguiente figura con cuatro subplots, ajusta el espaciado entre los subplots para evitar la superosición (tal y como ves en la figura), emplea `subplots_adjust` y los parámetros hspace y wspace.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,np.arctan(x))


plt.subplots_adjust(
    wspace=0.5,
    hspace= 0.3
)
plt.show();

# %% [markdown]
# ### Ejercicio 6:
#
# Reproduce la figura siguiente empleando sólo el estilo MATLAB (plt.\<funcion>\) y creando solo el contenido de los dos primeros gráficos (fila 1). Luego usa el estilo con métodos (objetos `axes`) para añadir el tercer gráfico.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
plt.figure(figsize=(5,5))

plt.subplot(2,1,1)
plt.plot(x,np.cos(x), label = "coseno")
plt.plot(x, np.sqrt(x), "orange", label = "raiz cuadrada")
plt.title("Raíz cuadrada y coseno")
plt.legend()

plt.subplot(2,1,2)
plt.plot(x, np.sin(x))
plt.title("Seno")

plt.subplots_adjust(
    hspace=0.5
)

plt.show()

# %% [markdown]
# ### Ejercicio 7
#
# Para terminar, reproduce la imagen de la figura

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
plt.figure(figsize=(5,5))

plt.plot(x, np.sin(x),"o" , color = "blue", markersize=9)
plt.plot(x, np.sin(x),"o" , markerfacecolor="yellow", markersize=7)
plt.title("Ejemplo de marcadores")
plt.show();
