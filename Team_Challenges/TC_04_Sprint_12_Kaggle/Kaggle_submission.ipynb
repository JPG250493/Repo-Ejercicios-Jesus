# %% [markdown]
# # **Kaggle – DataTops®**
# Tu TA ha decidido cambiar de aires y, por eso, ha comprado una tienda de portátiles. Sin embargo, su única especialidad es Data Science, por lo que ha decidido crear un modelo de ML para establecer los mejores precios.
#
# ¿Podrías ayudar a tu profe a mejorar ese modelo?

# %% [markdown]
# ## Aspectos importantes
# - Última submission:
#     - Mañana: 17 de febrero a las 5pm
#     - Tarde: 19 de febrero a las 5pm
# - **Enlace de la competición**: https://www.kaggle.com/t/c5cc87b50c4b4770bdc8f5acbe15577d
# - **Requisito**: Estar registrado en [Kaggle](https://www.kaggle.com/)

# %% [markdown]
# ## Métrica:
# El error cuadrático medio (RMSE, por sus siglas en inglés) es una medida de la desviación estándar de los residuos (errores de predicción). Los residuos representan la diferencia entre los valores observados y los valores predichos por el modelo. El RMSE indica qué tan dispersos están estos errores: cuanto menor es el RMSE, más cercanas están las predicciones a los valores reales. En otras palabras, el RMSE mide qué tan bien se ajusta la línea de regresión a los datos.
#
#
# $$ RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(\frac{d_i -f_i}{\sigma_i}\Big)^2}}$$

# %% [markdown]
# ## 1. Librerías

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import urllib.request

# %% [markdown]
# ## 2. Datos

# %%
# Para que funcione necesitas bajarte los archivos de datos de Kaggle
df = pd.read_csv("./data/train.csv", index_col = 'laptop_ID')

# %% [markdown]
# ### 2.1 Exploración de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_in_euros    912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB

# %%
df.head()
# Out:
#           Company        Product   TypeName  Inches   ScreenResolution  \
# laptop_ID
# 755            HP         250 G6   Notebook    15.6  Full HD 1920x1080
# 618          Dell  Inspiron 7559     Gaming    15.6  Full HD 1920x1080
# 909            HP    ProBook 450   Notebook    15.6  Full HD 1920x1080
# 2           Apple    Macbook Air  Ultrabook    13.3           1440x900
# 286          Dell  Inspiron 3567   Notebook    15.6  Full HD 1920x1080
#
#                                    Cpu   Ram               Memory  \
# laptop_ID
# 755           Intel Core i3 6006U 2GHz   8GB            256GB SSD
# 618        Intel Core i7 6700HQ 2.6GHz  16GB              1TB HDD
# 909         Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 2                 Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 286         Intel Core i3 6006U 2.0GHz   4GB              1TB HDD
#
#                                       Gpu       OpSys  Weight  Price_in_euros
# laptop_ID
# 755                 Intel HD Graphics 520  Windows 10  1.86kg          539.00
# 618        Nvidia GeForce GTX 960<U+039C>  Windows 10  2.59kg          879.01
# 909                  Nvidia GeForce 930MX  Windows 10  2.04kg          900.00
# 2                  Intel HD Graphics 6000       macOS  1.34kg          898.94
# 286                    AMD Radeon R5 M430       Linux  2.25kg          428.00

# %%
df.tail()
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 28           Dell       Inspiron 5570            Notebook    15.6
# 1160           HP         Spectre Pro  2 in 1 Convertible    13.3
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23             HP              255 G6            Notebook    15.6
# 229          Dell        Alienware 17              Gaming    17.3
#
#                           ScreenResolution                           Cpu  \
# laptop_ID
# 28                       Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 1160       Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz
# 78                       Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# 23                                1366x768  AMD E-Series E2-9000e 1.5GHz
# 229            IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                      Gpu       OpSys  \
# laptop_ID
# 28          8GB             256GB SSD           AMD Radeon 530  Windows 10
# 1160        8GB             256GB SSD    Intel HD Graphics 520  Windows 10
# 78          8GB               2TB HDD    Intel HD Graphics 620       No OS
# 23          4GB             500GB HDD            AMD Radeon R2       No OS
# 229        16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10
#
#            Weight  Price_in_euros
# laptop_ID
# 28          2.2kg          800.00
# 1160       1.48kg         1629.00
# 78          2.2kg          519.00
# 23         1.86kg          258.00
# 229        4.42kg         2456.34

# %%
df.describe()
# Out:
#            Inches  Price_in_euros
# count  912.000000      912.000000
# mean    14.981579     1111.724090
# std      1.436719      687.959172
# min     10.100000      174.000000
# 25%     14.000000      589.000000
# 50%     15.600000      978.000000
# 75%     15.600000     1483.942500
# max     18.400000     6099.000000

# %% [markdown]
# ### 2.3 Definir X e y

# %%
X = df.drop(['Price_in_euros'], axis=1)
y = df['Price_in_euros'].copy()
X.shape
# Out:
# (912, 11)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# ### 2.4 Dividir X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# 131                         Full HD 1920x1080
# ...                                       ...
# 578                                  1366x768
# 996                         Full HD 1920x1080
# 770                         Full HD 1920x1080
# 407                                  1366x768
# 418               IPS Panel Full HD 2560x1440
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 1118                Intel Core i7 6700HQ 2.6GHz   8GB               1TB HDD
# 153                 Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 275                        Intel Core i5 2.9GHz   8GB             512GB SSD
# 1100                 Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 131                  Intel Core i7 8550U 1.8GHz  16GB  256GB SSD +  2TB HDD
# ...                                         ...   ...                   ...
# 578        Intel Pentium Quad Core N3710 1.6GHz   8GB               2TB HDD
# 996                 AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
# 770                  Intel Core i7 7600U 2.8GHz  16GB             256GB SSD
# 407        Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 418                 Intel Core i7 7700HQ 2.8GHz   8GB             512GB SSD
#
#                                Gpu       OpSys  Weight
# laptop_ID
# 1118            AMD FirePro W6150M   Windows 7   3.0kg
# 153        Nvidia GeForce GTX 1050  Windows 10  2.56kg
# 275        Intel Iris Graphics 550       macOS  1.37kg
# 1100         Intel HD Graphics 520   Windows 7  1.54kg
# 131                 AMD Radeon 530  Windows 10   2.8kg
# ...                            ...         ...     ...
# 578          Intel HD Graphics 405  Windows 10  1.94kg
# 996                 AMD Radeon 530  Windows 10   2.2kg
# 770          Intel HD Graphics 620  Windows 10  1.18kg
# 407          Intel HD Graphics 500  Windows 10   2.2kg
# 418        Nvidia GeForce GT 940MX  Windows 10   1.7kg
#
# [729 rows x 11 columns]

# %%
y_train
# Out:
# laptop_ID
# 1118    2899.00
# 153     1249.26
# 275     1958.90
# 1100    1030.99
# 131     1396.00
#          ...
# 578      389.00
# 996      549.00
# 770     1859.00
# 407      306.00
# 418     1943.00
# Name: Price_in_euros, Length: 729, dtype: float64

# %% [markdown]
# ## 3. Procesado de datos

# %% [markdown]
# Nuestro target es la columna `Price_in_euros`

# %%
target = 'Price_in_euros'

# %%
X_train["Ram"].value_counts()
# Out:
# Ram
# 8GB     340
# 4GB     217
# 16GB    112
# 6GB      20
# 12GB     18
# 2GB      15
# 32GB      6
# 64GB      1
# Name: count, dtype: int64

# %%
X_train["RAM(GB)"] = X_train["Ram"].str.replace("GB","").astype(int)
X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# 131                         Full HD 1920x1080
# ...                                       ...
# 578                                  1366x768
# 996                         Full HD 1920x1080
# 770                         Full HD 1920x1080
# 407                                  1366x768
# 418               IPS Panel Full HD 2560x1440
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 1118                Intel Core i7 6700HQ 2.6GHz   8GB               1TB HDD
# 153                 Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 275                        Intel Core i5 2.9GHz   8GB             512GB SSD
# 1100                 Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 131                  Intel Core i7 8550U 1.8GHz  16GB  256GB SSD +  2TB HDD
# ...                                         ...   ...                   ...
# 578        Intel Pentium Quad Core N3710 1.6GHz   8GB               2TB HDD
# 996                 AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
# 770                  Intel Core i7 7600U 2.8GHz  16GB             256GB SSD
# 407        Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 418                 Intel Core i7 7700HQ 2.8GHz   8GB             512GB SSD
#
#                                Gpu       OpSys  Weight  RAM(GB)
# laptop_ID
# 1118            AMD FirePro W6150M   Windows 7   3.0kg        8
# 153        Nvidia GeForce GTX 1050  Windows 10  2.56kg       16
# 275        Intel Iris Graphics 550       macOS  1.37kg        8
# 1100         Intel HD Graphics 520   Windows 7  1.54kg        4
# 131                 AMD Radeon 530  Windows 10   2.8kg       16
# ...                            ...         ...     ...      ...
# 578          Intel HD Graphics 405  Windows 10  1.94kg        8
# 996                 AMD Radeon 530  Windows 10   2.2kg        6
# 770          Intel HD Graphics 620  Windows 10  1.18kg       16
# 407          Intel HD Graphics 500  Windows 10   2.2kg        4
# 418        Nvidia GeForce GT 940MX  Windows 10   1.7kg        8
#
# [729 rows x 12 columns]

# %%
X_train["Weight"].value_counts()
# Out:
# Weight
# 2.2kg     74
# 2.1kg     33
# 2.4kg     25
# 2.5kg     24
# 2.3kg     23
#           ..
# 0.91kg     1
# 1.70kg     1
# 2.15kg     1
# 1.94kg     1
# 1.18kg     1
# Name: count, Length: 148, dtype: int64

# %%
X_train["Weight(Kg)"] = X_train["Weight"].str.replace("kg","").astype(float)
X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# 131                         Full HD 1920x1080
# ...                                       ...
# 578                                  1366x768
# 996                         Full HD 1920x1080
# 770                         Full HD 1920x1080
# 407                                  1366x768
# 418               IPS Panel Full HD 2560x1440
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 1118                Intel Core i7 6700HQ 2.6GHz   8GB               1TB HDD
# 153                 Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 275                        Intel Core i5 2.9GHz   8GB             512GB SSD
# 1100                 Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 131                  Intel Core i7 8550U 1.8GHz  16GB  256GB SSD +  2TB HDD
# ...                                         ...   ...                   ...
# 578        Intel Pentium Quad Core N3710 1.6GHz   8GB               2TB HDD
# 996                 AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
# 770                  Intel Core i7 7600U 2.8GHz  16GB             256GB SSD
# 407        Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 418                 Intel Core i7 7700HQ 2.8GHz   8GB             512GB SSD
#
#                                Gpu       OpSys  Weight  RAM(GB)  Weight(Kg)
# laptop_ID
# 1118            AMD FirePro W6150M   Windows 7   3.0kg        8        3.00
# 153        Nvidia GeForce GTX 1050  Windows 10  2.56kg       16        2.56
# 275        Intel Iris Graphics 550       macOS  1.37kg        8        1.37
# 1100         Intel HD Graphics 520   Windows 7  1.54kg        4        1.54
# 131                 AMD Radeon 530  Windows 10   2.8kg       16        2.80
# ...                            ...         ...     ...      ...         ...
# 578          Intel HD Graphics 405  Windows 10  1.94kg        8        1.94
# 996                 AMD Radeon 530  Windows 10   2.2kg        6        2.20
# 770          Intel HD Graphics 620  Windows 10  1.18kg       16        1.18
# 407          Intel HD Graphics 500  Windows 10   2.2kg        4        2.20
# 418        Nvidia GeForce GT 940MX  Windows 10   1.7kg        8        1.70
#
# [729 rows x 13 columns]

# %%
features_num = ["Inches", "RAM(GB)", "Weight(Kg)"]

# %%
y_train.hist()
# Out:
# <Axes: >

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Modelado

# %% [markdown]
# ### 4.1 Baseline de modelos

# %%
#Tendríamos que haber limpiado desde el principio el dataframe para no duplicar el trabajo...
X_test["RAM(GB)"] = X_test["Ram"].str.replace("GB","").astype(int)
X_test["Weight(Kg)"] = X_test["Weight"].str.replace("kg","").astype(float)

X_test - X_test[features_num]

X_test
# Out:
#           Company                               Product            TypeName  \
# laptop_ID
# 451            HP                       Omen 15-AX205na              Gaming
# 802        Lenovo                        Yoga 510-15IKB  2 in 1 Convertible
# 723        Lenovo                         Thinkpad E470            Notebook
# 682            HP                         Pavilion X360  2 in 1 Convertible
# 1306         Asus   X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# ...           ...                                   ...                 ...
# 369            HP                                250 G6            Notebook
# 626          Acer  CB5-132T-C9KK (N3160/4GB/32GB/Chrome  2 in 1 Convertible
# 416        Lenovo                        Lenovo IdeaPad            Notebook
# 546        Lenovo                         Thinkpad E470            Notebook
# 260          Dell                           Vostro 5370           Ultrabook
#
#            Inches                           ScreenResolution  \
# laptop_ID
# 451          15.6                IPS Panel Full HD 1920x1080
# 802          15.6            Full HD / Touchscreen 1920x1080
# 723          14.0                IPS Panel Full HD 1920x1080
# 682          14.0  IPS Panel Full HD / Touchscreen 1920x1080
# 1306         15.6                                   1366x768
# ...           ...                                        ...
# 369          15.6                          Full HD 1920x1080
# 626          11.6             IPS Panel Touchscreen 1366x768
# 416          11.6                                   1366x768
# 546          14.0                IPS Panel Full HD 1920x1080
# 260          13.3                          Full HD 1920x1080
#
#                                             Cpu  Ram                Memory  \
# laptop_ID
# 451                 Intel Core i7 7700HQ 2.8GHz  8GB  128GB SSD +  1TB HDD
# 802                  Intel Core i5 7200U 2.5GHz  8GB             256GB SSD
# 723                  Intel Core i5 7200U 2.5GHz  8GB             256GB SSD
# 682                  Intel Core i3 7100U 2.4GHz  4GB             128GB SSD
# 1306       Intel Celeron Dual Core N3050 1.6GHz  4GB             500GB HDD
# ...                                         ...  ...                   ...
# 369                  Intel Core i5 7200U 2.5GHz  8GB               1TB HDD
# 626        Intel Celeron Quad Core N3160 1.6GHz  4GB    32GB Flash Storage
# 416        Intel Celeron Dual Core N3350 1.1GHz  2GB    32GB Flash Storage
# 546                  Intel Core i7 7500U 2.7GHz  8GB             256GB SSD
# 260                  Intel Core i5 8250U 1.6GHz  8GB             256GB SSD
#
#                                Gpu       OpSys  Weight  RAM(GB)  Weight(Kg)
# laptop_ID
# 451        Nvidia GeForce GTX 1050  Windows 10   2.2kg        8        2.20
# 802             AMD Radeon R7 M460  Windows 10  2.08kg        8        2.08
# 723           Nvidia GeForce 920MX  Windows 10  1.87kg        8        1.87
# 682           Nvidia GeForce 940MX  Windows 10  1.63kg        4        1.63
# 1306             Intel HD Graphics  Windows 10   2.2kg        4        2.20
# ...                            ...         ...     ...      ...         ...
# 369          Intel HD Graphics 620  Windows 10  1.86kg        8        1.86
# 626          Intel HD Graphics 400   Chrome OS  1.25kg        4        1.25
# 416          Intel HD Graphics 500  Windows 10  1.15kg        2        1.15
# 546           Nvidia GeForce 940MX  Windows 10  1.87kg        8        1.87
# 260         Intel UHD Graphics 620  Windows 10  1.41kg        8        1.41
#
# [183 rows x 13 columns]

# %%
X_train - X_train[features_num]
X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# 131                         Full HD 1920x1080
# ...                                       ...
# 578                                  1366x768
# 996                         Full HD 1920x1080
# 770                         Full HD 1920x1080
# 407                                  1366x768
# 418               IPS Panel Full HD 2560x1440
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 1118                Intel Core i7 6700HQ 2.6GHz   8GB               1TB HDD
# 153                 Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 275                        Intel Core i5 2.9GHz   8GB             512GB SSD
# 1100                 Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 131                  Intel Core i7 8550U 1.8GHz  16GB  256GB SSD +  2TB HDD
# ...                                         ...   ...                   ...
# 578        Intel Pentium Quad Core N3710 1.6GHz   8GB               2TB HDD
# 996                 AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
# 770                  Intel Core i7 7600U 2.8GHz  16GB             256GB SSD
# 407        Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 418                 Intel Core i7 7700HQ 2.8GHz   8GB             512GB SSD
#
#                                Gpu       OpSys  Weight  RAM(GB)  Weight(Kg)
# laptop_ID
# 1118            AMD FirePro W6150M   Windows 7   3.0kg        8        3.00
# 153        Nvidia GeForce GTX 1050  Windows 10  2.56kg       16        2.56
# 275        Intel Iris Graphics 550       macOS  1.37kg        8        1.37
# 1100         Intel HD Graphics 520   Windows 7  1.54kg        4        1.54
# 131                 AMD Radeon 530  Windows 10   2.8kg       16        2.80
# ...                            ...         ...     ...      ...         ...
# 578          Intel HD Graphics 405  Windows 10  1.94kg        8        1.94
# 996                 AMD Radeon 530  Windows 10   2.2kg        6        2.20
# 770          Intel HD Graphics 620  Windows 10  1.18kg       16        1.18
# 407          Intel HD Graphics 500  Windows 10   2.2kg        4        2.20
# 418        Nvidia GeForce GT 940MX  Windows 10   1.7kg        8        1.70
#
# [729 rows x 13 columns]

# %%
randomf = RandomForestRegressor(max_depth=6, random_state=42)

# %%
randomf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16812\1380521054.py in ?()
# ----> 1 randomf.fit(X_train, y_train)
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# --> 363         X, y = self._validate_data(
#     364             X,
#     365             y,
#     366             multi_output=True,
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1297         raise ValueError(
#    1298             f"{estimator_name} requires y to be passed, but the target y is None"
#    1299         )
#    1300
# -> 1301     X = check_array(
#    1302         X,
#    1303         accept_sparse=accept_sparse,
#    1304         accept_large_sparse=accept_large_sparse,
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'HP'

# %%
y_pred = randomf.predict(X_test)

# %% [markdown]
# ### 4.2 Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de ``RMSE``.

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# np.float64(745.5596559526152)

# %% [markdown]
# ### 4.3 Optimización (up to you 🫰🏻)

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ## 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("./data/test.csv", index_col = 'laptop_ID')
X_pred.head()
# Out:
#           Company                          Product            TypeName  \
# laptop_ID
# 209        Lenovo               Legion Y520-15IKBN              Gaming
# 1281         Acer                   Aspire ES1-531            Notebook
# 1168       Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No            Notebook
# 1231         Dell                    Inspiron 7579  2 in 1 Convertible
# 1020           HP                      ProBook 640            Notebook
#
#            Inches                           ScreenResolution  \
# laptop_ID
# 209          15.6                          Full HD 1920x1080
# 1281         15.6                                   1366x768
# 1168         15.6                                   1366x768
# 1231         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1020         14.0                          Full HD 1920x1080
#
#                                             Cpu   Ram     Memory  \
# laptop_ID
# 209                 Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD
# 1281       Intel Celeron Dual Core N3060 1.6GHz   4GB  500GB HDD
# 1168                 Intel Core i3 6006U 2.0GHz   4GB    1TB HDD
# 1231                 Intel Core i5 7200U 2.5GHz   8GB  256GB SSD
# 1020                 Intel Core i5 7200U 2.5GHz   4GB  256GB SSD
#
#                                Gpu       OpSys   Weight
# laptop_ID
# 209        Nvidia GeForce GTX 1060       No OS    2.4kg
# 1281         Intel HD Graphics 400       Linux    2.4kg
# 1168         Intel HD Graphics 520       No OS    1.9kg
# 1231         Intel HD Graphics 620  Windows 10  2.191kg
# 1020         Intel HD Graphics 620  Windows 10   1.95kg

# %%
X_pred.tail()
# Out:
#            Company          Product            TypeName  Inches  \
# laptop_ID
# 820            MSI      GE72MVR 7RG              Gaming    17.3
# 948        Toshiba  Tecra Z40-C-12X            Notebook    14.0
# 483           Dell  Precision M5520         Workstation    15.6
# 1017            HP      Probook 440            Notebook    14.0
# 421           Asus     ZenBook Flip  2 in 1 Convertible    13.3
#
#                                     ScreenResolution  \
# laptop_ID
# 820                                Full HD 1920x1080
# 948                      IPS Panel Full HD 1920x1080
# 483                                Full HD 1920x1080
# 1017                                        1366x768
# 421        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                    Cpu   Ram                Memory  \
# laptop_ID
# 820        Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948         Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 483        Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1017        Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 421         Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
#
#                                Gpu       OpSys  Weight
# laptop_ID
# 820        Nvidia GeForce GTX 1070  Windows 10   2.9kg
# 948          Intel HD Graphics 520  Windows 10  1.47kg
# 483            Nvidia Quadro M1200  Windows 10  1.78kg
# 1017         Intel HD Graphics 620  Windows 10  1.64kg
# 421          Intel HD Graphics 620  Windows 10  1.27kg

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           391 non-null    object
#  1   Product           391 non-null    object
#  2   TypeName          391 non-null    object
#  3   Inches            391 non-null    float64
#  4   ScreenResolution  391 non-null    object
#  5   Cpu               391 non-null    object
#  6   Ram               391 non-null    object
#  7   Memory            391 non-null    object
#  8   Gpu               391 non-null    object
#  9   OpSys             391 non-null    object
#  10  Weight            391 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 36.7+ KB

# %% [markdown]
#  ## 2. Replicar el procesado para ``test.csv``

# %%
X_pred["RAM(GB)"] = X_pred["Ram"].str.replace("GB","").astype(int)
X_pred["Weight(Kg)"] = X_pred["Weight"].str.replace("kg","").astype(float)
X_pred
# Out:
#            Company                          Product            TypeName  \
# laptop_ID
# 209         Lenovo               Legion Y520-15IKBN              Gaming
# 1281          Acer                   Aspire ES1-531            Notebook
# 1168        Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No            Notebook
# 1231          Dell                    Inspiron 7579  2 in 1 Convertible
# 1020            HP                      ProBook 640            Notebook
# ...            ...                              ...                 ...
# 820            MSI                      GE72MVR 7RG              Gaming
# 948        Toshiba                  Tecra Z40-C-12X            Notebook
# 483           Dell                  Precision M5520         Workstation
# 1017            HP                      Probook 440            Notebook
# 421           Asus                     ZenBook Flip  2 in 1 Convertible
#
#            Inches                           ScreenResolution  \
# laptop_ID
# 209          15.6                          Full HD 1920x1080
# 1281         15.6                                   1366x768
# 1168         15.6                                   1366x768
# 1231         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1020         14.0                          Full HD 1920x1080
# ...           ...                                        ...
# 820          17.3                          Full HD 1920x1080
# 948          14.0                IPS Panel Full HD 1920x1080
# 483          15.6                          Full HD 1920x1080
# 1017         14.0                                   1366x768
# 421          13.3  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 209                 Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 1281       Intel Celeron Dual Core N3060 1.6GHz   4GB             500GB HDD
# 1168                 Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 1231                 Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1020                 Intel Core i5 7200U 2.5GHz   4GB             256GB SSD
# ...                                         ...   ...                   ...
# 820                 Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948                  Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 483                 Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1017                 Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 421                  Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
#
#                                Gpu       OpSys   Weight  RAM(GB)  Weight(Kg)
# laptop_ID
# 209        Nvidia GeForce GTX 1060       No OS    2.4kg       16       2.400
# 1281         Intel HD Graphics 400       Linux    2.4kg        4       2.400
# 1168         Intel HD Graphics 520       No OS    1.9kg        4       1.900
# 1231         Intel HD Graphics 620  Windows 10  2.191kg        8       2.191
# 1020         Intel HD Graphics 620  Windows 10   1.95kg        4       1.950
# ...                            ...         ...      ...      ...         ...
# 820        Nvidia GeForce GTX 1070  Windows 10    2.9kg       16       2.900
# 948          Intel HD Graphics 520  Windows 10   1.47kg        4       1.470
# 483            Nvidia Quadro M1200  Windows 10   1.78kg        8       1.780
# 1017         Intel HD Graphics 620  Windows 10   1.64kg        4       1.640
# 421          Intel HD Graphics 620  Windows 10   1.27kg        8       1.270
#
# [391 rows x 13 columns]

# %%
X_pred - X_pred[features_num]
# Out:
#            Company  Cpu  Gpu  Inches  Memory  OpSys  Product  RAM(GB)  Ram  \
# laptop_ID
# 209            NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 1281           NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 1168           NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 1231           NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 1020           NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# ...            ...  ...  ...     ...     ...    ...      ...      ...  ...
# 820            NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 948            NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 483            NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 1017           NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
# 421            NaN  NaN  NaN     0.0     NaN    NaN      NaN        0  NaN
#
#            ScreenResolution  TypeName  Weight  Weight(Kg)
# laptop_ID
# 209                     NaN       NaN     NaN         0.0
# 1281                    NaN       NaN     NaN         0.0
# 1168                    NaN       NaN     NaN         0.0
# 1231                    NaN       NaN     NaN         0.0
# 1020                    NaN       NaN     NaN         0.0
# ...                     ...       ...     ...         ...
# 820                     NaN       NaN     NaN         0.0
# 948                     NaN       NaN     NaN         0.0
# 483                     NaN       NaN     NaN         0.0
# 1017                    NaN       NaN     NaN         0.0
# 421                     NaN       NaN     NaN         0.0
#
# [391 rows x 13 columns]

# %%
predictions_submit = randomf.predict(X_pred)
predictions_submit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 predictions_submit = randomf.predict(X_pred)
#       2 predictions_submit
#
# File h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\ensemble\_forest.py:1063, in ForestRegressor.predict(self, X)
#    1061 check_is_fitted(self)
#    1062 # Check data
# -> 1063 X = self._validate_X_predict(X)
#    1065 # Assign chunk of trees to jobs
#    1066 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)    544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)    606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File h:\RepoBootcamp\RepoEjercicios\venv\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names must be in the same order as they were in fit.

# %% [markdown]
# **¡OJO! ¿Por qué me da error?**

# %% [markdown]
# IMPORTANTE:
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO **BORRAR FILAS**, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER **391 FILAS**, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de ``train.csv`` usaste `index_col=0`, ¿tendré que hacer lo también para el `test.csv`?**

# %%
# ¿Qué opináis?
# ¿Sí, no?

# %% [markdown]
# ![wow.jpeg](attachment:wow.jpeg)

# %% [markdown]
# ## 3. **¿Qué es lo que subirás a Kaggle?**

# %% [markdown]
# **Para subir a Kaggle la predicción esta tendrá que tener una forma específica.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("data/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209          1949.1
# 1       1281           805.0
# 2       1168          1101.0
# 3       1231          1293.8
# 4       1020          1832.6

# %%
sample.shape
# Out:
# (391, 2)

# %% [markdown]
# ## 4. Mete tus predicciones en un dataframe llamado ``submission``.

# %%
#¿Cómo creamos la submission?
submission = pd.DataFrame(
    {"laptop_ID": X_pred.index, 
        "Price_in_euros" : predictions_submit})

# %%
submission.head()

# %%
submission.shape

# %% [markdown]
# ## 5. Pásale el CHEQUEADOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeador(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.

    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.

    Si no, LEE EL MENSAJE Y HAZLE CASO.

    Si aún no:
    - apaga tu ordenador,
    - date una vuelta,
    - enciendelo otra vez,
    - abre este notebook y
    - leelo todo de nuevo.
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.laptop_ID.all() == sample.laptop_ID.all():
                print("You're ready to submit!")
                df_to_submit.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://www.mihaileric.com/static/evaluation-meme-e0a350f278a36346e6d46b139b1d0da0-ed51e.jpg", "gfg.png")
                img = Image.open("gfg.png")
                img.show()
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto del TA: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `test.csv`. Lloro.")

# %%
chequeador(submission)
