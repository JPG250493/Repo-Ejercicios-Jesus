# %% [markdown]
# # **Kaggle – DataTops®**
# Tu TA ha decidido cambiar de aires y, por eso, ha comprado una tienda de portátiles. Sin embargo, su única especialidad es Data Science, por lo que ha decidido crear un modelo de ML para establecer los mejores precios.
#
# ¿Podrías ayudar a tu profe a mejorar ese modelo?

# %% [markdown]
# ## Aspectos importantes
# - Última submission:
#     - Mañana: 17 de febrero a las 5pm
#     - Tarde: 19 de febrero a las 5pm
# - **Enlace de la competición**: https://www.kaggle.com/t/c5cc87b50c4b4770bdc8f5acbe15577d
# - **Requisito**: Estar registrado en [Kaggle](https://www.kaggle.com/)

# %% [markdown]
# ## Métrica:
# El error cuadrático medio (RMSE, por sus siglas en inglés) es una medida de la desviación estándar de los residuos (errores de predicción). Los residuos representan la diferencia entre los valores observados y los valores predichos por el modelo. El RMSE indica qué tan dispersos están estos errores: cuanto menor es el RMSE, más cercanas están las predicciones a los valores reales. En otras palabras, el RMSE mide qué tan bien se ajusta la línea de regresión a los datos.
#
#
# $$ RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(\frac{d_i -f_i}{\sigma_i}\Big)^2}}$$

# %% [markdown]
# ## 1. Librerías

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import urllib.request

# %% [markdown]
# ## 2. Datos

# %%
# Para que funcione necesitas bajarte los archivos de datos de Kaggle
df = pd.read_csv("./data/train.csv", index_col = 'laptop_ID')

# %% [markdown]
# ### 2.1 Exploración de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_in_euros    912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB

# %%
df.head()
# Out:
#           Company        Product   TypeName  Inches   ScreenResolution  \
# laptop_ID
# 755            HP         250 G6   Notebook    15.6  Full HD 1920x1080
# 618          Dell  Inspiron 7559     Gaming    15.6  Full HD 1920x1080
# 909            HP    ProBook 450   Notebook    15.6  Full HD 1920x1080
# 2           Apple    Macbook Air  Ultrabook    13.3           1440x900
# 286          Dell  Inspiron 3567   Notebook    15.6  Full HD 1920x1080
#
#                                    Cpu   Ram               Memory  \
# laptop_ID
# 755           Intel Core i3 6006U 2GHz   8GB            256GB SSD
# 618        Intel Core i7 6700HQ 2.6GHz  16GB              1TB HDD
# 909         Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 2                 Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 286         Intel Core i3 6006U 2.0GHz   4GB              1TB HDD
#
#                                       Gpu       OpSys  Weight  Price_in_euros
# laptop_ID
# ...

# %%
df.tail()
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 28           Dell       Inspiron 5570            Notebook    15.6
# 1160           HP         Spectre Pro  2 in 1 Convertible    13.3
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23             HP              255 G6            Notebook    15.6
# 229          Dell        Alienware 17              Gaming    17.3
#
#                           ScreenResolution                           Cpu  \
# laptop_ID
# 28                       Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 1160       Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz
# 78                       Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# 23                                1366x768  AMD E-Series E2-9000e 1.5GHz
# 229            IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                      Gpu       OpSys  \
# laptop_ID
# ...

# %%
df.describe().T
# Out:
#                 count         mean         std    min    25%    50%  \
# Inches          912.0    14.981579    1.436719   10.1   14.0   15.6
# Price_in_euros  912.0  1111.724090  687.959172  174.0  589.0  978.0
#
#                       75%     max
# Inches            15.6000    18.4
# Price_in_euros  1483.9425  6099.0

# %% [markdown]
# ### 2.3 Definir X e y

# %%
X = df.drop(['Price_in_euros'], axis=1)
y = df['Price_in_euros'].copy()
X.shape
# Out:
# (912, 11)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# ### 2.4 Dividir X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size = 0.20, 
    random_state = 42
    )

# %%
X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# ...

# %%
y_train
# Out:
# laptop_ID
# 1118    2899.00
# 153     1249.26
# 275     1958.90
# 1100    1030.99
# 131     1396.00
#          ...
# 578      389.00
# 996      549.00
# 770     1859.00
# 407      306.00
# 418     1943.00
# Name: Price_in_euros, Length: 729, dtype: float64

# %% [markdown]
# ## 3. Procesado de datos

# %% [markdown]
# Nuestro target es la columna `Price_in_euros`

# %%
target = 'Price_in_euros'

# %%
X_train["Ram"].value_counts()
# Out:
# Ram
# 8GB     340
# 4GB     217
# 16GB    112
# 6GB      20
# 12GB     18
# 2GB      15
# 32GB      6
# 64GB      1
# Name: count, dtype: int64

# %%
X_train["RAM(GB)"] = X_train["Ram"].str.replace("GB","").astype(int)
X_test["RAM(GB)"] = X_test["Ram"].str.replace("GB","").astype(int)

X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# ...

# %%
X_train["Weight"].value_counts()
# Out:
# Weight
# 2.2kg     74
# 2.1kg     33
# 2.4kg     25
# 2.5kg     24
# 2.3kg     23
#           ..
# 0.91kg     1
# 1.70kg     1
# 2.15kg     1
# 1.94kg     1
# 1.18kg     1
# Name: count, Length: 148, dtype: int64

# %%
X_train["Weight(Kg)"] = X_train["Weight"].str.replace("kg","").astype(float)
X_test["Weight(Kg)"] = X_test["Weight"].str.replace("kg","").astype(float)
X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# ...

# %%
import re

def extraer_almacenamiento(memoria_str) : 
    ssd = 0
    hdd = 0

    memoria_str = str(memoria_str).lower()

    partes = memoria_str.split('+')

    for parte in partes:
        # Buscamos la cifra (entera o decimal) y si va seguida de gb o tb
        num_match = re.search(r'(\d+(?:\.\d+)?)\s*(gb|tb)', parte)
        
        if num_match:
            capacidad = float(num_match.group(1))
            unidad = num_match.group(2)
            
            # Si está en Teras, lo pasamos a Gigas (1 TB = 1024 GB)
            if unidad == 'tb':
                capacidad *= 1024
                
            # Metemos los gigas en el saco del SSD o del HDD según toque
            if 'ssd' in parte:
                ssd += capacidad
            elif 'hdd' in parte:
                hdd += capacidad
                
    # Devolvemos las dos cifras para crear las dos columnas
    return pd.Series([hdd, ssd])


# Aplicamos la función al DataFrame de X_train
X_train[['HDD_Memory(GB)', 'SSD_Memory(GB)']] = X_train['Memory'].apply(extraer_almacenamiento)
X_test[['HDD_Memory(GB)', 'SSD_Memory(GB)']] = X_test['Memory'].apply(extraer_almacenamiento)

X_train
# Out:
#           Company                         Product     TypeName  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17  Workstation    17.3
# 153          Dell                   Inspiron 5577       Gaming    15.6
# 275         Apple                     MacBook Pro    Ultrabook    13.3
# 1100           HP                   EliteBook 840     Notebook    14.0
# 131          Dell                   Inspiron 5770     Notebook    17.3
# ...           ...                             ...          ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)     Notebook    14.0
# 996        Lenovo               IdeaPad 320-15ABR     Notebook    15.6
# 770          Dell                   Latitude 7280    Ultrabook    12.5
# 407        Lenovo               IdeaPad 320-15IAP     Notebook    15.6
# 418        Lenovo                  Thinkpad T470p    Ultrabook    14.0
#
#                              ScreenResolution  \
# laptop_ID
# ...

# %%
X_train["Company"].value_counts()
# Out:
# Company
# Lenovo       162
# Dell         158
# HP           155
# Asus         101
# Acer          55
# Toshiba       31
# MSI           30
# Apple         13
# Mediacom       4
# Razer          4
# Xiaomi         3
# Samsung        3
# Microsoft      3
# Google         2
# Fujitsu        2
# Vero           2
# Chuwi          1
# Name: count, dtype: int64

# %%
X_train["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              412
# Gaming                113
# Ultrabook             113
# 2 in 1 Convertible     62
# Netbook                16
# Workstation            13
# Name: count, dtype: int64

# %%
X_train = pd.get_dummies(X_train, columns=['TypeName'], dtype=int)
X_test = pd.get_dummies(X_test, columns=['TypeName'], dtype=int)

# %%
X_train["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                280
# 1366x768                                         170
# IPS Panel Full HD 1920x1080                      130
# Full HD / Touchscreen 1920x1080                   26
# IPS Panel Full HD / Touchscreen 1920x1080         25
# 1600x900                                          14
# Quad HD+ / Touchscreen 3200x1800                  10
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel 4K Ultra HD 3840x2160                    5
# 4K Ultra HD / Touchscreen 3840x2160                5
# Touchscreen 1366x768                               5
# 1440x900                                           4
# Touchscreen 2560x1440                              4
# IPS Panel 1366x768                                 4
# IPS Panel Retina Display 2560x1600                 3
# IPS Panel Retina Display 2304x1440                 3
# ...

# %%
# 1. Creamos la columna IPS (1 si contiene "IPS", 0 si no)
# Usamos astype(int) para convertir los True/False en 1/0
X_train['IPS'] = X_train['ScreenResolution'].str.contains('IPS', case=False).astype(int)
X_test['IPS'] = X_test['ScreenResolution'].str.contains('IPS', case=False).astype(int)

# 2. Creamos la columna Touchscreen de la misma forma
X_train['Touchscreen'] = X_train['ScreenResolution'].str.contains('Touchscreen', case=False).astype(int)
X_test['Touchscreen'] = X_test['ScreenResolution'].str.contains('Touchscreen', case=False).astype(int)

# 3. Extraemos la resolución con expresiones regulares
# Buscamos el patrón "número x número" (ej. 1920x1080)
# Esto crea un DataFrame temporal con dos columnas (una para el ancho y otra para el alto)
resolucion = X_train['ScreenResolution'].str.extract(r'(\d+)x(\d+)')
res_text = X_test['ScreenResolution'].str.extract(r'(\d+)x(\d+)')

# 4. Asignamos los valores extraídos a nuestras nuevas columnas y los pasamos a número (integer)
X_train['Resolucion(Ancho)'] = resolucion[0].astype(int) # Ej: 1920
X_train['Resolucion(Alto)']  = resolucion[1].astype(int)  # Ej: 1080
X_test['Resolucion(Ancho)'] = res_text[0].astype(int) # Ej: 1920
X_test['Resolucion(Alto)']  = res_text[1].astype(int)  # Ej: 1080


# Creamos la columna Retina (1 si es Retina, 0 si no)
X_train['Retina'] = X_train['ScreenResolution'].str.contains('Retina', case=False).astype(int)
X_test['Retina'] = X_test['ScreenResolution'].str.contains('Retina', case=False).astype(int)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
print(X_train["Cpu"].value_counts().to_string())
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              100
# Intel Core i7 7700HQ 2.8GHz              82
# Intel Core i7 7500U 2.7GHz               77
# Intel Core i5 8250U 1.6GHz               46
# Intel Core i7 8550U 1.8GHz               40
# Intel Core i5 6200U 2.3GHz               40
# Intel Core i7 6500U 2.5GHz               35
# Intel Core i3 6006U 2GHz                 34
# Intel Core i7 6700HQ 2.6GHz              22
# Intel Celeron Dual Core N3060 1.6GHz     21
# Intel Core i3 7100U 2.4GHz               17
# Intel Celeron Dual Core N3350 1.1GHz     15
# Intel Core i5 7300HQ 2.5GHz              13
# Intel Pentium Quad Core N4200 1.1GHz     10
# Intel Core i3 6006U 2.0GHz               10
# Intel Celeron Dual Core N3050 1.6GHz      9
# Intel Pentium Quad Core N3710 1.6GHz      9
# Intel Core i7 6600U 2.6GHz                8
# Intel Core i7 7600U 2.8GHz                8
# Intel Core i5 6300U 2.4GHz                7
# Intel Core i3 7130U 2.7GHz                6
# ...

# %%
X_train['Cpu_Marca'] = X_train['Cpu'].str.extract(r'(Intel|AMD)')
X_test['Cpu_Marca'] = X_test['Cpu'].str.extract(r'(Intel|AMD)')

X_train['Cpu_GHz'] = X_train['Cpu'].str.extract(r'(\d+(?:\.\d+)?)\s*GHz').astype(float)
X_test['Cpu_GHz'] = X_test['Cpu'].str.extract(r'(\d+(?:\.\d+)?)\s*GHz').astype(float)

def analizar_cpu(texto_cpu):
    texto = str(texto_cpu)
    
    # --- 1. EVALUAR LA CATEGORÍA ---
    if 'Xeon' in texto or 'i7' in texto:
        categoria = 'Gama Alta (i7 / Xeon)'
    elif 'i5' in texto:
        categoria = 'Gama Media (i5)'
    elif 'i3' in texto:
        categoria = 'Gama Entrada (i3)'
    elif 'Celeron' in texto or 'Pentium' in texto or 'Atom' in texto or 'Core M' in texto:
        categoria = 'Gama Baja (Básico/Bajo Consumo)'
    elif 'AMD' in texto:
        if 'Ryzen' in texto or 'FX' in texto:
            categoria = 'AMD Rendimiento (Ryzen/FX)'
        else:
            categoria = 'AMD Básico (Series A/E)'
    else:
        categoria = 'Otros'
        
    # --- 2. EVALUAR EL SUFIJO ---
    # Solo nos interesa buscar esto en los procesadores Intel Core
    if 'Intel Core' in texto:
        if 'HQ' in texto or 'HK' in texto:
            sufijo = 'Alto Rendimiento (HQ/HK)'
        elif 'U' in texto:
            sufijo = 'Bajo Consumo (U)'
        elif 'Y' in texto:
            sufijo = 'Ultra Bajo Consumo (Y)'
        else:
            sufijo = 'Estándar / Otro'
    else:
        sufijo = 'No Aplica'
        
    # Devolvemos ambos valores empaquetados en una Serie de Pandas
    return pd.Series([categoria, sufijo])

# Aplicamos la función y le asignamos directamente las DOS columnas nuevas
X_train[['Cpu_Categoria', 'Cpu_Sufijo']] = X_train['Cpu'].apply(analizar_cpu)
X_test[['Cpu_Categoria', 'Cpu_Sufijo']] = X_test['Cpu'].apply(analizar_cpu)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
X_train = pd.get_dummies(X_train, columns=['Cpu_Marca'], dtype=int)
X_test = pd.get_dummies(X_test, columns=['Cpu_Marca'], dtype=int)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
print(X_train["Gpu"].value_counts().to_string())
# Out:
# Gpu
# Intel HD Graphics 620             150
# Intel HD Graphics 520             110
# Intel UHD Graphics 620             43
# Nvidia GeForce GTX 1050            32
# Nvidia GeForce 940MX               24
# Intel HD Graphics 400              23
# Nvidia GeForce GTX 1060            21
# Nvidia GeForce GTX 1070            20
# Nvidia GeForce GTX 1050 Ti         20
# Intel HD Graphics 500              20
# AMD Radeon 530                     19
# Intel HD Graphics                  18
# AMD Radeon R5 M430                 15
# Nvidia GeForce 930MX               15
# Nvidia GeForce GTX 960M            10
# Intel HD Graphics 515              10
# Nvidia GeForce MX150                8
# Intel HD Graphics 505               8
# Nvidia GeForce 920MX                8
# Intel HD Graphics 615               7
# Intel HD Graphics 405               7
# Nvidia GeForce GTX 950M             6
# Nvidia GeForce GTX 980M             6
# AMD Radeon 520                      6
# ...

# %%
def analizar_gpu(texto_gpu):
    texto = str(texto_gpu)
    
    # --- 1. EVALUAR LA MARCA ---
    if 'Intel' in texto:
        marca = 'Intel'
    elif 'Nvidia' in texto:
        marca = 'Nvidia'
    elif 'AMD' in texto:
        marca = 'AMD'
    else:
        marca = 'Otra' # Por si hay alguna ARM rara
        
    # --- 2. EVALUAR EL TIPO Y LA GAMA (LA CHICHA) ---
    
    # 2.1 - INTEL (Casi todas son integradas básicas)
    if marca == 'Intel':
        # Iris Pro / Iris Plus son algo mejores que las HD normales
        if 'Iris' in texto:
            gama = 'Integrada Media (Iris)'
        else:
            gama = 'Integrada Básica (HD/UHD)'
            
    # 2.2 - NVIDIA (La reina de las dedicadas)
    elif marca == 'Nvidia':
        # Las Quadro son carísimas, para estaciones de trabajo (diseño 3D, CAD)
        if 'Quadro' in texto:
            gama = 'Dedicada Workstation (Quadro)'
        # Las GTX (como la 1050, 1060, 1070) son de Gaming y encarecen mucho el PC
        elif 'GTX' in texto:
            gama = 'Dedicada Gaming (GTX)'
        # Las "M", "MX" o "GT" (ej. 940MX, MX150) son dedicadas de gama de entrada
        else:
            gama = 'Dedicada Básica (M/MX)'
            
    # 2.3 - AMD (Tienen de todo)
    elif marca == 'AMD':
        # FirePro es la competencia de las Quadro (Workstation)
        if 'FirePro' in texto:
            gama = 'Dedicada Workstation (FirePro)'
        # La serie RX (ej. RX 580) es la competencia de las GTX (Gaming)
        elif 'RX' in texto:
            gama = 'Dedicada Gaming (RX)'
        # Radeon R7, R9 o la serie 500 (ej. 530, 540) suelen ser dedicadas de entrada/media
        elif 'R7' in texto or 'R9' in texto or '530' in texto or '520' in texto:
            gama = 'Dedicada Básica (R7/Serie 500)'
        # R2, R4, R5 suelen ser integradas básicas
        else:
            gama = 'Integrada Básica (Radeon R2/R4/R5)'
            
    else:
        gama = 'Desconocida'

    # Devolvemos ambas columnas
    return pd.Series([marca, gama])

# Aplicamos la magia y creamos las dos columnas nuevas
X_train[['Gpu_Marca', 'Gpu_Gama']] = X_train['Gpu'].apply(analizar_gpu)
X_test[['Gpu_Marca', 'Gpu_Gama']] = X_test['Gpu'].apply(analizar_gpu)

# Y para rematar, el One-Hot Encoding de siempre:
X_train = pd.get_dummies(X_train, columns=['Gpu_Marca'], dtype=int)
X_test = pd.get_dummies(X_test, columns=['Gpu_Marca'], dtype=int)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
# Definimos el diccionario con la jerarquía (1 es lo más básico, 5 lo más top)
orden_cpu = {
    'Gama Baja (Básico/Bajo Consumo)': 1,
    'AMD Básico (Series A/E)': 1,
    'Gama Entrada (i3)': 2,
    'Gama Media (i5)': 3,
    'AMD Rendimiento (Ryzen/FX)': 3, # Lo empatamos con el i5 aprox
    'Gama Alta (i7 / Xeon)': 4,
    'Otros': 0 # Por si hay algún dato vacío o muy raro
}

# Aplicamos el diccionario a la columna. Pandas sustituirá el texto por el número.
X_train['Cpu_Categoria_Num'] = X_train['Cpu_Categoria'].map(orden_cpu)
X_test['Cpu_Categoria_Num'] = X_test['Cpu_Categoria'].map(orden_cpu)

# Para los sufijos de Intel, también podemos hacer un orden (por potencia/consumo)
orden_sufijo = {
    'Ultra Bajo Consumo (Y)': 1,
    'Bajo Consumo (U)': 2,
    'Estándar / Otro': 3,
    'Alto Rendimiento (HQ/HK)': 4,
    'No Aplica': 0
}
X_train['Cpu_Sufijo_Num'] = X_train['Cpu_Sufijo'].map(orden_sufijo)
X_test['Cpu_Sufijo_Num'] = X_test['Cpu_Sufijo'].map(orden_sufijo)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
# Jerarquía de GPUs
orden_gpu = {
    'Integrada Básica (HD/UHD)': 1,
    'Integrada Básica (Radeon R2/R4/R5)': 1,
    'Integrada Media (Iris)': 2,
    'Dedicada Básica (M/MX)': 3,
    'Dedicada Básica (R7/Serie 500)': 3,
    'Dedicada Gaming (GTX)': 4,
    'Dedicada Gaming (RX)': 4,
    'Dedicada Workstation (Quadro)': 5, # Las ponemos top porque encarecen muchísimo el PC
    'Dedicada Workstation (FirePro)': 5,
    'Desconocida': 0
}

# Mapeamos
X_train['Gpu_Gama_Num'] = X_train['Gpu_Gama'].map(orden_gpu)
X_test['Gpu_Gama_Num'] = X_test['Gpu_Gama'].map(orden_gpu)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
X_train['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      596
# No OS            39
# Linux            37
# Windows 7        24
# Chrome OS        14
# macOS             7
# Mac OS X          6
# Windows 10 S      5
# Android           1
# Name: count, dtype: int64

# %%
def agrupar_os(texto_os):
    texto = str(texto_os)
    
    # 1. Todo lo que sea de Microsoft, al mismo saco
    if 'Windows' in texto:
        return 'Windows'
        
    # 2. Todo lo de Apple, junto
    elif 'Mac' in texto or 'macOS' in texto:
        return 'Mac'
        
    # 3. Equipos sin sistema operativo de pago (suelen ser más baratos)
    elif 'No OS' in texto or 'Linux' in texto:
        return 'Linux / No OS'
        
    # 4. Lo residual (Chrome OS, Android...)
    else:
        return 'Otros'

# Aplicamos la función para limpiar la columna
X_train['OpSys_Limpio'] = X_train['OpSys'].apply(agrupar_os)
X_test['OpSys_Limpio'] = X_test['OpSys'].apply(agrupar_os)

# Y AHORA SÍ, aplicamos el One-Hot Encoding a la columna limpia
# Así solo engordamos el dataset en 4 columnas súper claras en lugar de 9 ruidosas
X_train = pd.get_dummies(X_train, columns=['OpSys_Limpio'], dtype=int)
X_test = pd.get_dummies(X_test, columns=['OpSys_Limpio'], dtype=int)

X_train
# Out:
#           Company                         Product  Inches  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3
# 153          Dell                   Inspiron 5577    15.6
# 275         Apple                     MacBook Pro    13.3
# 1100           HP                   EliteBook 840    14.0
# 131          Dell                   Inspiron 5770    17.3
# ...           ...                             ...     ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0
# 996        Lenovo               IdeaPad 320-15ABR    15.6
# 770          Dell                   Latitude 7280    12.5
# 407        Lenovo               IdeaPad 320-15IAP    15.6
# 418        Lenovo                  Thinkpad T470p    14.0
#
#                              ScreenResolution  \
# laptop_ID
# 1118              IPS Panel Full HD 1920x1080
# 153                         Full HD 1920x1080
# 275        IPS Panel Retina Display 2560x1600
# 1100                        Full HD 1920x1080
# ...

# %%
print(X_train["Product"].value_counts().to_string())
# Out:
# Product
# XPS 13                                           20
# Inspiron 3567                                    17
# 250 G6                                           12
# ProBook 450                                      12
# EliteBook 840                                    11
# Legion Y520-15IKBN                               11
# Vostro 3568                                      10
# Satellite Pro                                    10
# Inspiron 5570                                     9
# Alienware 17                                      8
# ThinkPad X1                                       7
# EliteBook 850                                     6
# Inspiron 5567                                     6
# Inspiron 3552                                     6
# ProBook 470                                       6
# ThinkPad Yoga                                     6
# Vostro 5568                                       6
# IdeaPad 320-17IKB                                 6
# ...

# %%
X_train_sucia = X_train.copy()
X_test_sucia = X_test.copy()

X_train.columns
# Out:
# Index(['Company', 'Product', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'RAM(GB)', 'Weight(Kg)',
#        'HDD_Memory(GB)', 'SSD_Memory(GB)', 'TypeName_2 in 1 Convertible',
#        'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
#        'TypeName_Ultrabook', 'TypeName_Workstation', 'IPS', 'Touchscreen',
#        'Resolucion(Ancho)', 'Resolucion(Alto)', 'Retina', 'Cpu_GHz',
#        'Cpu_Categoria', 'Cpu_Sufijo', 'Cpu_Marca_AMD', 'Cpu_Marca_Intel',
#        'Gpu_Gama', 'Gpu_Marca_AMD', 'Gpu_Marca_Intel', 'Gpu_Marca_Nvidia',
#        'Cpu_Categoria_Num', 'Cpu_Sufijo_Num', 'Gpu_Gama_Num',
#        'OpSys_Limpio_Linux / No OS', 'OpSys_Limpio_Mac', 'OpSys_Limpio_Otros',
#        'OpSys_Limpio_Windows'],
#       dtype='object')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 729 entries, 1118 to 418
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Company                      729 non-null    object
#  1   Product                      729 non-null    object
#  2   Inches                       729 non-null    float64
#  3   ScreenResolution             729 non-null    object
#  4   Cpu                          729 non-null    object
#  5   Ram                          729 non-null    object
#  6   Memory                       729 non-null    object
#  7   Gpu                          729 non-null    object
#  8   OpSys                        729 non-null    object
#  9   Weight                       729 non-null    object
#  10  RAM(GB)                      729 non-null    int64
#  11  Weight(Kg)                   729 non-null    float64
#  12  HDD_Memory(GB)               729 non-null    float64
# ...

# %%
X_train = X_train.drop(['ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Cpu_Categoria', 'Cpu_Sufijo', 'Gpu_Gama'], axis = 1)
X_test = X_test.drop(['ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Cpu_Categoria', 'Cpu_Sufijo', 'Gpu_Gama'], axis = 1)

# %%
X_train.columns
# Out:
# Index(['Company', 'Product', 'Inches', 'RAM(GB)', 'Weight(Kg)',
#        'HDD_Memory(GB)', 'SSD_Memory(GB)', 'TypeName_2 in 1 Convertible',
#        'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
#        'TypeName_Ultrabook', 'TypeName_Workstation', 'IPS', 'Touchscreen',
#        'Resolucion(Ancho)', 'Resolucion(Alto)', 'Retina', 'Cpu_GHz',
#        'Cpu_Marca_AMD', 'Cpu_Marca_Intel', 'Gpu_Marca_AMD', 'Gpu_Marca_Intel',
#        'Gpu_Marca_Nvidia', 'Cpu_Categoria_Num', 'Cpu_Sufijo_Num',
#        'Gpu_Gama_Num', 'OpSys_Limpio_Linux / No OS', 'OpSys_Limpio_Mac',
#        'OpSys_Limpio_Otros', 'OpSys_Limpio_Windows'],
#       dtype='object')

# %%
display(X_train[['Company', 'Product', 'Inches', 'RAM(GB)', 'Weight(Kg)',
       'HDD_Memory(GB)', 'SSD_Memory(GB)', 'TypeName_2 in 1 Convertible',
       'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
       'TypeName_Ultrabook', 'TypeName_Workstation', 'IPS', 'Touchscreen',
       'Resolucion(Ancho)', 'Resolucion(Alto)', 'Retina', 'Cpu_GHz',
       'Cpu_Marca_AMD', 'Cpu_Marca_Intel', 'Gpu_Marca_AMD', 'Gpu_Marca_Intel',
       'Gpu_Marca_Nvidia', 'Cpu_Categoria_Num', 'Cpu_Sufijo_Num',
       'Gpu_Gama_Num', 'OpSys_Limpio_Linux / No OS', 'OpSys_Limpio_Mac',
       'OpSys_Limpio_Otros', 'OpSys_Limpio_Windows']])
# Out:
#           Company                         Product  Inches  RAM(GB)  \
# laptop_ID
# 1118           HP                        ZBook 17    17.3        8
# 153          Dell                   Inspiron 5577    15.6       16
# 275         Apple                     MacBook Pro    13.3        8
# 1100           HP                   EliteBook 840    14.0        4
# 131          Dell                   Inspiron 5770    17.3       16
# ...           ...                             ...     ...      ...
# 578            HP  14-am079na (N3710/8GB/2TB/W10)    14.0        8
# 996        Lenovo               IdeaPad 320-15ABR    15.6        6
# 770          Dell                   Latitude 7280    12.5       16
# 407        Lenovo               IdeaPad 320-15IAP    15.6        4
# 418        Lenovo                  Thinkpad T470p    14.0        8
#
#            Weight(Kg)  HDD_Memory(GB)  SSD_Memory(GB)  \
# laptop_ID
# 1118             3.00          1024.0             0.0
# ...

# %%
features_num = ['Inches', 'RAM(GB)', 'Weight(Kg)',
       'HDD_Memory(GB)', 'SSD_Memory(GB)', 'TypeName_2 in 1 Convertible',
       'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
       'TypeName_Ultrabook', 'TypeName_Workstation', 'IPS', 'Touchscreen',
       'Resolucion(Ancho)', 'Resolucion(Alto)', 'Retina', 'Cpu_GHz',
       'Cpu_Marca_AMD', 'Cpu_Marca_Intel', 'Gpu_Marca_AMD', 'Gpu_Marca_Intel',
       'Gpu_Marca_Nvidia', 'Cpu_Categoria_Num', 'Cpu_Sufijo_Num',
       'Gpu_Gama_Num', 'OpSys_Limpio_Linux / No OS', 'OpSys_Limpio_Mac',
       'OpSys_Limpio_Otros', 'OpSys_Limpio_Windows']

# %%
y_train.hist()
# Out:
# <Axes: >

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Modelado

# %% [markdown]
# ### 4.1 Baseline de modelos

# %%
# #Tendríamos que haber limpiado desde el principio el dataframe para no duplicar el trabajo...
# X_test["RAM(GB)"] = X_test["Ram"].str.replace("GB","").astype(int)
# X_test["Weight(Kg)"] = X_test["Weight"].str.replace("kg","").astype(float)
# X_test[['HDD_Memory(GB)', 'SSD_Memory(GB)']] = X_test['Memory'].apply(extraer_almacenamiento)

# X_test - X_test[features_num]

print(X_test.columns)
# Out:
# Index(['Company', 'Product', 'Inches', 'RAM(GB)', 'Weight(Kg)',
#        'HDD_Memory(GB)', 'SSD_Memory(GB)', 'TypeName_2 in 1 Convertible',
#        'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
#        'TypeName_Ultrabook', 'TypeName_Workstation', 'IPS', 'Touchscreen',
#        'Resolucion(Ancho)', 'Resolucion(Alto)', 'Retina', 'Cpu_GHz',
#        'Cpu_Marca_AMD', 'Cpu_Marca_Intel', 'Gpu_Marca_AMD', 'Gpu_Marca_Intel',
#        'Gpu_Marca_Nvidia', 'Cpu_Categoria_Num', 'Cpu_Sufijo_Num',
#        'Gpu_Gama_Num', 'OpSys_Limpio_Linux / No OS', 'OpSys_Limpio_Mac',
#        'OpSys_Limpio_Otros', 'OpSys_Limpio_Windows'],
#       dtype='object')

# %%
# X_train - X_train[features_num]
# X_train

# %%
randomf = RandomForestRegressor(max_depth=6, random_state=42)

# %%
randomf.fit(X_train[features_num], y_train)
# Out:
# RandomForestRegressor(max_depth=6, random_state=42)

# %%
y_pred = randomf.predict(X_test[features_num])

# %% [markdown]
# ### 4.2 Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de ``RMSE``.

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# np.float64(366.90806758944626)

# %% [markdown]
# ### 4.3 Optimización (up to you 🫰🏻)

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ## 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("./data/test.csv", index_col = 'laptop_ID')
X_pred.head()
# Out:
#           Company                          Product            TypeName  \
# laptop_ID
# 209        Lenovo               Legion Y520-15IKBN              Gaming
# 1281         Acer                   Aspire ES1-531            Notebook
# 1168       Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No            Notebook
# 1231         Dell                    Inspiron 7579  2 in 1 Convertible
# 1020           HP                      ProBook 640            Notebook
#
#            Inches                           ScreenResolution  \
# laptop_ID
# 209          15.6                          Full HD 1920x1080
# 1281         15.6                                   1366x768
# 1168         15.6                                   1366x768
# 1231         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1020         14.0                          Full HD 1920x1080
#
#                                             Cpu   Ram     Memory  \
# laptop_ID
# 209                 Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD
# ...

# %%
X_pred.tail()
# Out:
#            Company          Product            TypeName  Inches  \
# laptop_ID
# 820            MSI      GE72MVR 7RG              Gaming    17.3
# 948        Toshiba  Tecra Z40-C-12X            Notebook    14.0
# 483           Dell  Precision M5520         Workstation    15.6
# 1017            HP      Probook 440            Notebook    14.0
# 421           Asus     ZenBook Flip  2 in 1 Convertible    13.3
#
#                                     ScreenResolution  \
# laptop_ID
# 820                                Full HD 1920x1080
# 948                      IPS Panel Full HD 1920x1080
# 483                                Full HD 1920x1080
# 1017                                        1366x768
# 421        IPS Panel Full HD / Touchscreen 1920x1080
#
#                                    Cpu   Ram                Memory  \
# laptop_ID
# 820        Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948         Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# ...

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           391 non-null    object
#  1   Product           391 non-null    object
#  2   TypeName          391 non-null    object
#  3   Inches            391 non-null    float64
#  4   ScreenResolution  391 non-null    object
#  5   Cpu               391 non-null    object
#  6   Ram               391 non-null    object
#  7   Memory            391 non-null    object
#  8   Gpu               391 non-null    object
#  9   OpSys             391 non-null    object
#  10  Weight            391 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 36.7+ KB

# %% [markdown]
#  ## 2. Replicar el procesado para ``test.csv``

# %%
X_pred["RAM(GB)"] = X_pred["Ram"].str.replace("GB","").astype(int)
X_pred["Weight(Kg)"] = X_pred["Weight"].str.replace("kg","").astype(float)
X_pred[['HDD_Memory(GB)', 'SSD_Memory(GB)']] = X_pred['Memory'].apply(extraer_almacenamiento)
X_pred = pd.get_dummies(X_pred, columns = ["TypeName"], dtype = int)
X_pred['IPS'] = X_pred['ScreenResolution'].str.contains('IPS', case=False).astype(int)
X_pred['Touchscreen'] = X_pred['ScreenResolution'].str.contains('Touchscreen', case=False).astype(int)
resolucion = X_pred['ScreenResolution'].str.extract(r'(\d+)x(\d+)')
X_pred['Resolucion(Ancho)'] = resolucion[0].astype(int) # Ej: 1920
X_pred['Resolucion(Alto)']  = resolucion[1].astype(int)  # Ej: 1080
X_pred['Retina'] = X_pred['ScreenResolution'].str.contains('Retina', case=False).astype(int)
X_pred['Cpu_Marca'] = X_pred['Cpu'].str.extract(r'(Intel|AMD)')
X_pred['Cpu_GHz'] = X_pred['Cpu'].str.extract(r'(\d+(?:\.\d+)?)\s*GHz').astype(float)
X_pred[['Cpu_Categoria', 'Cpu_Sufijo']] = X_pred['Cpu'].apply(analizar_cpu)
X_pred = pd.get_dummies(X_pred, columns=['Cpu_Marca'], dtype=int)
X_pred[['Gpu_Marca', 'Gpu_Gama']] = X_pred['Gpu'].apply(analizar_gpu)
X_pred = pd.get_dummies(X_pred, columns=['Gpu_Marca'], dtype=int)
X_pred['Cpu_Categoria_Num'] = X_pred['Cpu_Categoria'].map(orden_cpu)
X_pred['Cpu_Sufijo_Num'] = X_pred['Cpu_Sufijo'].map(orden_sufijo)
X_pred['Gpu_Gama_Num'] = X_pred['Gpu_Gama'].map(orden_gpu)
X_pred['OpSys_Limpio'] = X_pred['OpSys'].apply(agrupar_os)
X_pred = pd.get_dummies(X_pred, columns=['OpSys_Limpio'], dtype=int)

X_pred
# Out:
#            Company                          Product  Inches  \
# laptop_ID
# 209         Lenovo               Legion Y520-15IKBN    15.6
# 1281          Acer                   Aspire ES1-531    15.6
# 1168        Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No    15.6
# 1231          Dell                    Inspiron 7579    15.6
# 1020            HP                      ProBook 640    14.0
# ...            ...                              ...     ...
# 820            MSI                      GE72MVR 7RG    17.3
# 948        Toshiba                  Tecra Z40-C-12X    14.0
# 483           Dell                  Precision M5520    15.6
# 1017            HP                      Probook 440    14.0
# 421           Asus                     ZenBook Flip    13.3
#
#                                     ScreenResolution  \
# laptop_ID
# 209                                Full HD 1920x1080
# 1281                                        1366x768
# 1168                                        1366x768
# ...

# %%
X_pred - X_pred[features_num]
# Out:
#            Company  Cpu  Cpu_Categoria  Cpu_Categoria_Num  Cpu_GHz  \
# laptop_ID
# 209            NaN  NaN            NaN                  0      0.0
# 1281           NaN  NaN            NaN                  0      0.0
# 1168           NaN  NaN            NaN                  0      0.0
# 1231           NaN  NaN            NaN                  0      0.0
# 1020           NaN  NaN            NaN                  0      0.0
# ...            ...  ...            ...                ...      ...
# 820            NaN  NaN            NaN                  0      0.0
# 948            NaN  NaN            NaN                  0      0.0
# 483            NaN  NaN            NaN                  0      0.0
# 1017           NaN  NaN            NaN                  0      0.0
# 421            NaN  NaN            NaN                  0      0.0
#
#            Cpu_Marca_AMD  Cpu_Marca_Intel  Cpu_Sufijo  Cpu_Sufijo_Num  Gpu  \
# laptop_ID
# ...

# %%
predictions_submit = randomf.predict(X_pred[features_num])
predictions_submit
# Out:
# array([1701.43864434,  333.97068716,  447.81923145, 1112.96461971,
#         925.36012327,  468.46706166,  900.33474288,  988.11866912,
#        1477.14407964,  332.70468215, 2519.45267016, 1437.83918385,
#         501.63327765, 1622.01860341,  800.12575692,  760.41369814,
#        1888.88750999, 1470.77456778, 1555.69196319,  796.00479362,
#        1469.23822939,  331.96647425,  747.37792695, 1615.35750204,
#         542.05592261,  812.26206568,  519.01884153,  612.36574927,
#        2357.51847461, 1048.47275056, 1923.99466502,  487.20375221,
#         889.62437571, 3171.17508964, 2004.8618909 , 1787.91161661,
#         711.92065812, 1726.95799816,  937.63082431, 1474.33958679,
#         765.10430837, 1071.57165395,  479.8761972 , 1050.53722606,
#        1199.8979135 , 1120.05926774,  999.29102365,  492.52948017,
#         962.90662744,  429.74567899, 2071.46482332,  812.73265353,
#        1185.76582603,  674.65719782, 1692.40857672, 1559.68368503,
# ...

# %% [markdown]
# **¡OJO! ¿Por qué me da error?**

# %% [markdown]
# IMPORTANTE:
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO **BORRAR FILAS**, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER **391 FILAS**, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de ``train.csv`` usaste `index_col=0`, ¿tendré que hacer lo también para el `test.csv`?**

# %%
# ¿Qué opináis?
# ¿Sí, no?

# %% [markdown]
# ## 3. **¿Qué es lo que subirás a Kaggle?**

# %% [markdown]
# **Para subir a Kaggle la predicción esta tendrá que tener una forma específica.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("data/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209          1949.1
# 1       1281           805.0
# 2       1168          1101.0
# 3       1231          1293.8
# 4       1020          1832.6

# %%
sample.shape
# Out:
# (391, 2)

# %% [markdown]
# ## 4. Mete tus predicciones en un dataframe llamado ``submission``.

# %%
#¿Cómo creamos la submission?
submission = pd.DataFrame(
    {"laptop_ID": X_pred.index, 
        "Price_in_euros" : predictions_submit})

# %%
submission.head()
# Out:
#    laptop_ID  Price_in_euros
# 0        209     1701.438644
# 1       1281      333.970687
# 2       1168      447.819231
# 3       1231     1112.964620
# 4       1020      925.360123

# %%
submission.shape
# Out:
# (391, 2)

# %% [markdown]
# ## 5. Pásale el CHEQUEADOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeador(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.

    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.

    Si no, LEE EL MENSAJE Y HAZLE CASO.

    Si aún no:
    - apaga tu ordenador,
    - date una vuelta,
    - enciendelo otra vez,
    - abre este notebook y
    - leelo todo de nuevo.
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.laptop_ID.all() == sample.laptop_ID.all():
                print("You're ready to submit!")
                df_to_submit.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://www.mihaileric.com/static/evaluation-meme-e0a350f278a36346e6d46b139b1d0da0-ed51e.jpg", "gfg.png")
                img = Image.open("gfg.png")
                img.show()
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto del TA: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `test.csv`. Lloro.")

# %%
chequeador(submission)
# Out:
# You're ready to submit!
